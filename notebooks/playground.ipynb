# %%
import pandas as pd

file_path= "/scratch/akash/metadata/010d6dbb50674c8ed041b1e5f0a7896e.parquet"

df = pd.read_parquet(file_path, engine='pyarrow')

df["url"]
# Out:
# 0         https://static.codepre.com/uploads/1595781771.png
# 1         https://lh4.ggpht.com/9mX9NrvDxMjnWbtkxLat8o2b...
# 2         https://m.media-amazon.com/images/I/71Zi0pNi44...
# 3         https://ae04.alicdn.com/kf/H9aca05330fbc49a6ba...
# 4         https://www.newsline-media.com/img-get2/I0000i...
#                                 ...
# 528797    https://clipartart.com/images/free-clipart-of-...
# 528798    https://www.ibraggiotti.com//media/catalog/pro...
# 528799    https://www.livingspaces.com/api/image?recId=1...
# 528800    https://i.pinimg.com/236x/0d/ea/77/0dea776bb49...
# 528801    http://i00.i.aliimg.com/photo/v1/60006493826/T...
# Name: url, Length: 528802, dtype: object

# %%
df.head()
# Out:
#                                 uid  \
# 0  64748b36e8c6a0e126164407a4911fc8
# 1  9f2704fa536065648963583b039f20be
# 2  c779d31c7a2256df8bc7f0aa73f2988a
# 3  8b737904edd0d8a8bd41b6482fac686e
# 4  c859b9bd5c505f46e3895c3d2a44ad13
#
#                                                  url  \
# 0  https://static.codepre.com/uploads/1595781771.png
# 1  https://lh4.ggpht.com/9mX9NrvDxMjnWbtkxLat8o2b...
# 2  https://m.media-amazon.com/images/I/71Zi0pNi44...
# 3  https://ae04.alicdn.com/kf/H9aca05330fbc49a6ba...
# 4  https://www.newsline-media.com/img-get2/I0000i...
#
#                                                 text  original_width  \
# 0      Install and configure October CMS on CentOS 8            1024
# 1             Slots Paradise™ - screenshot thumbnail             174
# 2  White HeadbandWhite Baptism HeadbandChristenin...            1500
# 3  usb 3 0 to sata dual bay hard drive dock exter...             200
# 4  DUNDEE, SCOTLAND, APRIL 2021: An increase in t...             180
#
#    original_height  clip_b32_similarity_score  clip_l14_similarity_score  \
# 0              583                   0.263672                   0.247559
# 1              310                   0.318359                   0.269775
# 2             1166                   0.291992                   0.258301
# 3              200                   0.317383                   0.263428
# 4              120                   0.315186                   0.303711
#
#                                          face_bboxes  \
# 0                                                 []
# 1  [[0.5823844075202942, 0.4352933466434479, 0.88...
# 2  [[0.06728982925415039, 0.625583291053772, 0.08...
# 3                                                 []
# 4                                                 []
#
#                                               sha256
# 0  c84253691515429f1b7ff455c7bb3bb3204287044dd740...
# 1  026973a67430fce8192eccac7ce370e99e33a98007aa7d...
# 2  b0db19240ab12e4906ed8ce29a8cbedfec83315b4acd2c...
# 3  db25aa6e3854846c9d400cc63eca8455e1173e58316006...
# 4  34283e8d994e3b3b4991a2de9cd83e1f05b459aa1faf6f...
